# %%
### applies pre-processing steps to images
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
import os
# Out:
# /home/tschernn/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
### binarization
# select threshold number

threshold = 172
source_dir = 'writable_area_sonstige' 

def binarize_dir(threshold, dir):

    os.makedirs(f'preprocessed_imgs/binarized_imgs/{dir}', exist_ok=True)
        
    for file in os.listdir(dir):
        img_name = str(file)
        img = cv.imread(dir + '/' + img_name, cv.IMREAD_GRAYSCALE)
        retval, thresh = cv.threshold(img, threshold, 255, cv.THRESH_BINARY)
        cv.imwrite(f'preprocessed_imgs/binarized_imgs/{dir}/' + img_name, thresh)
        print(f'successfully wrote preprocessed_imgs/binarized_imgs/{dir}/' + img_name)

binarize_dir(threshold, source_dir)
# Out:
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_d3ecc79211c73844916047138cb78736.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_fc4953e46dbe01b4fdd9972a69153d10.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_0c25f94590a98253ffd26417ee7a9c7d.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_031376c09d0d916554848934a2860045.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_0493eb82a51aebfd530ceb5b0a4218f7.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_8d3cb7ca4e8f43b63332687a098d40c8.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_2cfe57baf854ad7b9ccdbdf208f250d5.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_b9796a392e658a002ed9b711adb8c8f2.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_cf3367f2becca65a45a32ada7727fa12.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_cbf312f1e60afe430940b24245f77c9b.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_7826de0fcc95207bd3e07aec54e72e0a.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_35bb5b13f88ca51e931658582add59da.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_1a958b271bddb4d0cb277e2d97dd9a9e.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_54f580230d36b526395664e9fa91ee51.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_afc7a32e57721277f4da104a461b600b.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_1e53f612a816f02d730f94b53a4fa1fd.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_c368183cd9649665f822f5fc9f5d55d5.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_ed7e56e5555255fe33e944354342591c.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_7822c1bcfc1e92f40512fa367a39c1e0.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_adcc10826d002a455437867e0f0e2fa6.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_1a5c313537aaacb51a513f925fdd2978.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_74f51ca770b5e6c4b506e3b5a218978d.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_092d1a1ded5cc32adad73560fba0b23f.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_1830bcdd11e2316e0d05c576ec84bb60.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_20eccefe7c5bf1962c47d486abb3fe98.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_589e8cfd9e625ed1b38d8de56da6014f.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_1021266c38387c8ea5aa6d8540afdaff.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_4345dc33a5c90117075704b4d334d86a.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_7c9d78803ef1f0203f326700278032cf.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_efcb2440d83b114fec42358684fbbff7.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_05828bbff2d0fc8475810bf44e724ca4.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_af83b472ca04f8940b09d1ceb346fcbe.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_6abedce6cbdeb2194c82bd156151d7d8.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_58127a983538b1d63c787912114f491b.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_46f9162f72e9a0c1c0f611c52ac6cd34.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_439e74aed0dc3d957f90e06725f4ddf5.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_c496287ef2be2502c34b39cf0fb192082.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_5459bad3c0257236bd8028d8d9dde3eb.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_6ce8b3e191d3f767cabc6119981045a5.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_3a4a5c8d81b197a90aefb0394d76c30f.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_546d2bfc2d8c719735c600fa2ac34537.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_83b2329a4dcc138d6da0949c5d664487.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_d2f8386157d8fca1d5f6941d90114435.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_68d9e98137cc08d127b7c4b0b4afa99e.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_39ff09bf2835eaae059df88f0477f44f.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_850efd0d2f67dd5d789e30df605355052.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_fe61a1adda7877dcf8b34dc2d899992e.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_bf777c45ba3ac3e63f226c82a0e3b2ce.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_c82b6bd10456e82a4b507ca1ce238743.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_031376c09d0d916554848934a28600452.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_91b66019d3b8f53fe232c07806e558cc.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_f1a494b946ca344686d0965250f89c5a.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_9409af3065c7782533649e46fe5b3205.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_add4428610454e6ed47e486d48651b73.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_850efd0d2f67dd5d789e30df60535505.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_4d574c3f65567486650c6f5faa0ec604.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_cd4ea1649386414a1cead93568365631.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_cf53b39fb8ecb3fd58649a352a1c9d1a.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_ac627c4dde0cda52f9e20be975dee19a.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_aefb8fafdd5fdf475b4dfc1be662c742.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_48705975fea1730d92f9012cd32f3709.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_5a8e9bbdd9575d8bf2a3edb3e1fcd485.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_e55ec61fa69d44e8b53166beb4aa3d68.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_c496287ef2be2502c34b39cf0fb19208.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_2858d53edc37e4faceaddf760f26982b.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_98326b350291235025e78019a1ef4bd6.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_611727135028075bd72f9ae29bccb5e7.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_1226204da4259d196a7b543c60657c88.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_fe7324e1afb6f77c3ea7e30834f79407.jpg
# successfully wrote preprocessed_imgs/binarized_imgs/writable_area_sonstige/wa_147230b1ebaa527588e5fa01b443e4de.jpg

# %%
### visualize results
result_dir = os.listdir(f'preprocessed_imgs/binarized_imgs/{source_dir}')
plt.figure(figsize = (20, 20));
num = 16 # num of items to visualize
for i in range(1, num): 
    plt.subplot(4, 4, i); # number of rows, number of columns, item number
    img = mpimg.imread(f'preprocessed_imgs/binarized_imgs/{source_dir}/' + result_dir[i])
    plt.imshow(img, cmap = plt.cm.binary);
plt.show()
